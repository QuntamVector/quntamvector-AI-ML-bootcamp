# %% [markdown]
# ## contact list
# {"pritam":"189738646","rohit":"73927344"}
#
#
# KEY --> VALUE
#
# student: {"name":"Manasa", "age: 26 ,"Marks":99}
# "
# student[name]--> "Manasa"

# %%
menu = {
    "Butter chiken": 280,
    "Panner": 220,
    "Garlic Naan" : 40,
    "Biriyani" : 300,
}

# %%
menu["Butter chiken"]
# Out:
# 280

# %%
menu["Biriyani"]
# Out:
# 300

# %%
type(menu)
# Out:
# dict

# %%
student = {
    "name" : "Pritam",
    "age"  : 30,
    "address" : "Banglore", 
}

# %%
student["age"]
# Out:
# 30

# %%
## CREATE A DICTIONARY

IPL_TEAMS = {
    "CSK" : "Chennai Super Kings",
    "MI" : "Mumbai Indians",
    "RCB" : "Royal Challengers Bangalore",
    "KKR" : "Kolkata Knight Riders",
    "SRH" : "Sunrisers Hyderabad",
    "DC" : "Delhi Capitals",
    "RR" : "Rajasthan Royals",
    "PBKS" : "Punjab Kings",
}

# %%
type(IPL_TEAMS)
# Out:
# dict

# %%
print(IPL_TEAMS["RCB"])
# Out:
# Royal Challengers Bangalore

# %%
print(len(IPL_TEAMS))
# Out:
# 8

# %%
if "GT" in IPL_TEAMS:
    print("GT is in the list")
else:    
    print("GT is not in the list")
# Out:
# GT is not in the list

# %%
student = {
    "name" : "Pritam",
    "age"  : 30,
    "address" : "Banglore",
    "phone" : 1234567890,
    "passed" : True,
}

# %%
print(student["name"])
# Out:
# Pritam

# %%
print(student.get("name"))
# Out:
# Pritam

# %%
print(student["cgpa"]) # This will throw an error
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 print(student["cgpa"]) # This will throw an error
#
# KeyError: 'cgpa'

# %%
print(student.get("cgpa"))
# Out:
# None

# %%
print(student.get("cgpa","N/A"))

# %%
print(student.get("cgpa"))

# %%
print(student["name"])

# %%
student

# %%
student = {
    "name" : "Pritam",
    "age"  : 30,
    "address" : "Banglore",
    "phone" : 1234567890,
    "passed" : True,
}

# %%
print(student)

# %%
student["name"]
