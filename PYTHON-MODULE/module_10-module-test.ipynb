# %%
# calculate the area of a circle with a given radius
radius = 5
area = 3.41 * radius ** 2
print("The area of the circle with radius", radius, "is", area)
# Out:
# The area of the circle with radius 5 is 85.25

# %%
radius = 10
area = 3.41 * radius ** 2
print("The area of the circle with radius", radius, "is", area)
# Out:
# The area of the circle with radius 10 is 341.0

# %%
import math
print(math.sqrt(16))
print(math.sqrt(25))
print(math.pi)
# Out:
# 4.0
# 5.0
# 3.141592653589793

# %%
import numpy as np
np.array([1, 2, 3, 4, 5])
# Out:
# array([1, 2, 3, 4, 5])

# %%
from math import sqrt
print(sqrt(16))
print(pi)
# Out:
# 4.0
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 3
#       1 from math import sqrt
#       2 print(sqrt(16))
# ----> 3 print(pi)
#
# NameError: name 'pi' is not defined

# %%
from math import  *
print(sqrt(16))
print(pi)
# Out:
# 4.0
# 3.141592653589793
